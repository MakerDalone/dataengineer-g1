# %%
venta = {
    "id": "V-101",
    "region": "Lima",
    "cantidad" : 100,
    "precio" : 205.5
}

# %%
venta["id"]
# Out:
# 'V-101'

# %%
venta["region"]
# Out:
# 'Lima'

# %%
venta["precio"]
# Out:
# 205.5

# %%
venta["region"] = "Arequipa"
venta
# Out:
# {'id': 'V-101', 'region': 'Arequipa', 'cantidad': 100, 'precio': 205.5}

# %%
venta.get("descuento", 0)
# Out:
# 0

# %%
venta.get("moneda", "USD")
# Out:
# 'USD'

# %%
venta["moneda"] = "PEN"

# %%
venta.get("moneda", "USD")
# Out:
# 'PEN'

# %%
del venta["moneda"]
venta
# Out:
# {'id': 'V-101', 'region': 'Arequipa', 'cantidad': 100, 'precio': 205.5}

# %%
"moneda " in venta
# Out:
# False

# %%
list(venta.keys())
# Out:
# ['id', 'region', 'cantidad', 'precio']

# %%
list(venta.values())
# Out:
# ['V-101', 'Arequipa', 100, 205.5]

# %%
venta
# Out:
# {'id': 'V-101', 'region': 'Arequipa', 'cantidad': 100, 'precio': 205.5}

# %%
#venta["cantidad"]=500
#venta["precio"] = 1000

venta.update(
    {"cantidad": 400 ,
     "precio": 1000
     }
)
venta
# Out:
# {'id': 'V-101', 'region': 'Arequipa', 'cantidad': 400, 'precio': 1000}

# %%
#venta["precio"] = 5000

venta.setdefault("descuento",1000)
venta.setdefault("precio",5000)
venta
# Out:
# {'id': 'V-101',
#  'region': 'Arequipa',
#  'cantidad': 400,
#  'precio': 1000,
#  'descuento': 1000}

# %%
pedido = {
    "id" : "P-9",
    "cliente" : {
        "nombre" : "Marisol",
        "ciudad" : "Lima",
        "edad" : "18"
    },
    "items" : [
        {
            "sku" : "A1",
            "precio" : 19.5
        },
        {
            "sku" : "A2",
            "precio" : 20.55
        }
    ]
}
pedido
# Out:
# {'id': 'P-9',
#  'cliente': {'nombre': 'Marisol', 'ciudad': 'Lima', 'edad': '18'},
#  'items': [{'sku': 'A1', 'precio': 19.5}, {'sku': 'A2', 'precio': 20.55}]}

# %%
list(pedido.keys())
# Out:
# ['id', 'cliente', 'items']

# %%
list(pedido["cliente"])
# Out:
# ['nombre', 'ciudad', 'edad']

# %%
list(pedido["cliente"].keys())
# Out:
# ['nombre', 'ciudad', 'edad']

# %%
pedido["cliente"]["nombre"]
# Out:
# 'Marisol'

# %%
pedido["cliente"]["edad"]
# Out:
# '18'

# %%
pedido["items"][1]
# Out:
# {'sku': 'A2', 'precio': 20.55}

# %%
pedido["items"][1]["precio"]
# Out:
# 20.55
