# %%
regiones = [
    "Lima",
    "Cuzco",
    "Piura",
    "Loreto"
]

vacia = []

mixta = ["V-1001",2 , 23.25, True]

# %%
regiones[0]
# Out:
# 'Lima'

# %%
regiones[-1]
# Out:
# 'Loreto'

# %%
"Cuzco" in regiones
# Out:
# True

# %%
ventas = [32, 1450, 89.5, 2100, 5000]

# %%
ventas.append([1,3])
ventas
# Out:
# [32, 1450, 89.5, 2100, 5000, [1, 3]]

# %%
ventas.extend([4,5])
ventas
# Out:
# [32, 1450, 89.5, 2100, 5000, [1, 3], 4, 5]

# %%
ventas.insert(0, 55)
ventas
# Out:
# [55, 32, 1450, 89.5, 2100, 5000, [1, 3], 4, 5]

# %%
ventas.insert(2, 999)
ventas
# Out:
# [55, 32, 999, 1450, 89.5, 2100, 5000, [1, 3], 4, 5]

# %%
ventas.remove(55)
ventas
# Out:
# [32, 999, 1450, 89.5, 2100, 5000, [1, 3], 4, 5]

# %%
ventas.remove([1,3])
ventas
# Out:
# [32, 999, 1450, 89.5, 2100, 5000, 4, 5]

# %%
ventas.sort()
ventas
# Out:
# [4, 5, 32, 89.5, 999, 1450, 2100, 5000]

# %%
ventas.sort(reverse=True)
ventas
# Out:
# [5000, 2100, 1450, 999, 89.5, 32, 5, 4]

# %%
ventas_asc = sorted(ventas)
ventas_asc
# Out:
# [4, 5, 32, 89.5, 999, 1450, 2100, 5000]

# %%
ventas
# Out:
# [5000, 2100, 1450, 999, 89.5, 32, 5, 4]

# %%
ventas.pop()
ventas
# Out:
# [1, 2, 5, 4]

# %%
sum(ventas)
# Out:
# 9675.5

# %%
ventas = [1,2,5,4,3]
sum(ventas)
# Out:
# 15

# %%
min(ventas)
# Out:
# 1

# %%
max(ventas)
# Out:
# 5

# %%
ventas.pop()
ventas
# Out:
# [1, 2, 5]

# %%
ventas.count(2)
# Out:
# 1
