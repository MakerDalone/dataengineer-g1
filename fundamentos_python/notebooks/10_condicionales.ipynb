# %%
color = "rosado"

if color == "verde":
    premio = 10
elif color == "azul":
    premio = 5
else:
    premio = 0

print(premio)
# Out:
# 0

# %%
cantidad = 1000
precio = 50

# %%
if cantidad > 0 and precio is not None:
    total = cantidad * precio
    print(total)
# Out:
# 50000

# %%
registros = []

print("Llenar registros de hoy día...")
registros.extend([]1,2,3,4,5)

if registros:
    print("Procesando...")
else:
    print("Los registros estan vacíos")
